# %%
# Imports
import numpy as np 
import nibabel as nib
import os
import torch
import monai
import shutil

from scipy.ndimage import binary_dilation
from scipy.ndimage import generate_binary_structure

# %% [markdown]
# # Tumor mask data preparation

# %%
# All paths 
all_scans_path = "L:/Basic/divi/jstoker/slicer_pdac/Master Students WS 24/Martijn/data/Training/all_scans"
all_segmentations_path = "L:/Basic/divi/jstoker/slicer_pdac/Master Students WS 24/Martijn/data/Training/all_segmentations"

tumor_segmentations_path = "L:/Basic/divi/jstoker/slicer_pdac/Master Students WS 24/Martijn/data/Training/tumor_segmentations"
paired_tumor_scans_path = "L:/Basic/divi/jstoker/slicer_pdac/Master Students WS 24/Martijn/data/Training/paired_tumor_scans"

# %%
"""
Segments the liver, creates a bounding box based on the liver, and segments only the tumors within the bounding box.
"""

struct = np.ones((3, 3, 3))  # 3x3x3 cube

# Generates a 3D spherical-like connectivity structure
structure = generate_binary_structure(3, 1)  # 3D, with connectivity=1

for scan in os.listdir(all_scans_path):
    print(f"Currently processing: {scan}")
    
    # Load image and corresponding segmentation
    image = nib.load(os.path.join(all_scans_path, scan))

    segm_filename = scan.replace("_0000", "")
    segmentation = nib.load(os.path.join(all_segmentations_path, segm_filename))

    image_data = image.get_fdata()
    segmentation_data = segmentation.get_fdata()

    # Create a liver mask (labels 12 and 13)
    liver_mask = (segmentation_data == 12) | (segmentation_data == 13)

    # Apply the liver mask to the image
    liver_image = np.copy(image_data)
    liver_image[~liver_mask] = 0

    # Find the indices of the liver mask
    mask_indices = np.argwhere(liver_mask)

    # Calculate the bounding box for the liver
    min_indices = mask_indices.min(axis=0)
    max_indices = mask_indices.max(axis=0)

    # Crop the liver image using the bounding box
    cropped_liver_image = liver_image[min_indices[0]:max_indices[0]+1, min_indices[1]:max_indices[1]+1, min_indices[2]:max_indices[2]+1]

    # Crop the segmentation data using the same bounding box
    cropped_segmentation_data = segmentation_data[min_indices[0]:max_indices[0]+1, min_indices[1]:max_indices[1]+1, min_indices[2]:max_indices[2]+1]

    # Create a tumor mask (label 13) within the cropped liver region
    tumor_mask = (cropped_segmentation_data == 13)

    # Apply binary dilation to the tumor mask
    dilated_tumor_mask = binary_dilation(tumor_mask, structure=structure, iterations=10)

    # Apply the dilated tumor mask to the cropped liver image
    tumor_image = np.copy(cropped_liver_image)
    tumor_image[~dilated_tumor_mask.astype(bool)] = 0

    # Create a new NIfTI image for the tumor segmentation
    new_image = nib.Nifti1Image(tumor_image, affine=image.affine, header=image.header)

    # Save the new NIfTI image to a file with the original name
    new_filename = (scan.split(".")[0])[0:-5] + "_tumor.nii.gz"
    output_file_path = os.path.join(tumor_segmentations_path, new_filename)
    nib.save(new_image, output_file_path)
# Out:
# Currently processing: CAESAR326_1_0000.nii.gz
# Currently processing: CAESAR187_0_0000.nii.gz
# Currently processing: CAESAR360_1_0000.nii.gz
# Currently processing: CAESAR357_1_0000.nii.gz
# Currently processing: CAESAR012_1_0000.nii.gz
# Currently processing: CAESAR429_1_0000.nii.gz
# Currently processing: CAESAR453_1_0000.nii.gz
# Currently processing: CAESAR442_0_0000.nii.gz
# Currently processing: CAESAR569_1_0000.nii.gz
# Currently processing: CAESAR257_2_0000.nii.gz
# Currently processing: CAESAR226_0_0000.nii.gz
# Currently processing: CAESAR583_0_0000.nii.gz
# Currently processing: CAESAR419_0_0000.nii.gz
# Currently processing: CAESAR537_0_0000.nii.gz
# Currently processing: CAESAR269_1_0000.nii.gz
# Currently processing: CAESAR372_0_0000.nii.gz
# Currently processing: CAESAR404_1_0000.nii.gz
# Currently processing: CAESAR512_1_0000.nii.gz
# Currently processing: CAESAR417_1_0000.nii.gz
# Currently processing: CAESAR001_1_0000.nii.gz
# Currently processing: CAESAR299_0_0000.nii.gz
# Currently processing: CAESAR463_2_0000.nii.gz
# Currently processing: CAESAR049_1_0000.nii.gz
# Currently processing: CAESAR413_0_0000.nii.gz
# Currently processing: CAESAR500_1_0000.nii.gz
# Currently processing: CAESAR418_0_0000.nii.gz
# Currently processing: CAESAR143_0_0000.nii.gz
# Currently processing: CAESAR454_1_0000.nii.gz
# Currently processing: CAESAR353_2_0000.nii.gz
# Currently processing: CAESAR108_0_0000.nii.gz
# Currently processing: CAESAR352_0_0000.nii.gz
# Currently processing: CAESAR183_0_0000.nii.gz
# Currently processing: CAESAR344_0_0000.nii.gz
# Currently processing: CAESAR512_2_0000.nii.gz
# Currently processing: CAESAR083_1_0000.nii.gz
# Currently processing: CAESAR330_1_0000.nii.gz
# Currently processing: CAESAR135_0_0000.nii.gz
# Currently processing: CAESAR037_1_0000.nii.gz
# Currently processing: CAESAR086_1_0000.nii.gz
# Currently processing: CAESAR232_2_0000.nii.gz
# Currently processing: CAESAR007_0_0000.nii.gz
# Currently processing: CAESAR226_1_0000.nii.gz
# Currently processing: CAESAR242_1_0000.nii.gz
# Currently processing: CAESAR176_1_0000.nii.gz
# Currently processing: CAESAR447_2_0000.nii.gz
# Currently processing: CAESAR325_2_0000.nii.gz
# Currently processing: CAESAR284_0_0000.nii.gz
# Currently processing: CAESAR466_0_0000.nii.gz
# Currently processing: CAESAR457_2_0000.nii.gz
# Currently processing: CAESAR484_1_0000.nii.gz
# Currently processing: CAESAR498_1_0000.nii.gz
# Currently processing: CAESAR371_0_0000.nii.gz
# Currently processing: CAESAR342_1_0000.nii.gz
# Currently processing: CAESAR050_0_0000.nii.gz
# Currently processing: CAESAR560_0_0000.nii.gz
# Currently processing: CAESAR224_1_0000.nii.gz
# Currently processing: CAESAR507_1_0000.nii.gz
# Currently processing: CAESAR074_0_0000.nii.gz
# Currently processing: CAESAR152_2_0000.nii.gz
# Currently processing: CAESAR010_1_0000.nii.gz
# Currently processing: CAESAR475_0_0000.nii.gz
# Currently processing: CAESAR479_0_0000.nii.gz
# Currently processing: CAESAR097_0_0000.nii.gz
# Currently processing: CAESAR067_0_0000.nii.gz
# Currently processing: CAESAR269_0_0000.nii.gz
# Currently processing: CAESAR089_0_0000.nii.gz
# Currently processing: CAESAR110_0_0000.nii.gz
# Currently processing: CAESAR165_2_0000.nii.gz
# Currently processing: CAESAR047_1_0000.nii.gz
# Currently processing: CAESAR519_0_0000.nii.gz
# Currently processing: CAESAR144_0_0000.nii.gz
# Currently processing: CAESAR183_1_0000.nii.gz
# Currently processing: CAESAR385_0_0000.nii.gz
# Currently processing: CAESAR062_1_0000.nii.gz
# Currently processing: CAESAR136_1_0000.nii.gz
# Currently processing: CAESAR044_0_0000.nii.gz
# Currently processing: CAESAR083_0_0000.nii.gz
# Currently processing: CAESAR104_1_0000.nii.gz
# Currently processing: CAESAR078_0_0000.nii.gz
# Currently processing: CAESAR407_0_0000.nii.gz
# Currently processing: CAESAR225_1_0000.nii.gz
# Currently processing: CAESAR209_1_0000.nii.gz
# Currently processing: CAESAR131_0_0000.nii.gz
# Currently processing: CAESAR433_1_0000.nii.gz
# Currently processing: CAESAR174_0_0000.nii.gz
# Currently processing: CAESAR421_2_0000.nii.gz
# Currently processing: CAESAR481_0_0000.nii.gz
# Currently processing: CAESAR027_0_0000.nii.gz
# Currently processing: CAESAR370_1_0000.nii.gz
# Currently processing: CAESAR443_0_0000.nii.gz
# Currently processing: CAESAR063_1_0000.nii.gz
# Currently processing: CAESAR438_0_0000.nii.gz
# Currently processing: CAESAR358_1_0000.nii.gz
# Currently processing: CAESAR386_0_0000.nii.gz
# Currently processing: CAESAR194_0_0000.nii.gz
# Currently processing: CAESAR051_0_0000.nii.gz
# Currently processing: CAESAR257_0_0000.nii.gz
# Currently processing: CAESAR140_0_0000.nii.gz
# Currently processing: CAESAR218_0_0000.nii.gz
# Currently processing: CAESAR077_2_0000.nii.gz
# Currently processing: CAESAR084_1_0000.nii.gz
# Currently processing: CAESAR550_0_0000.nii.gz
# Currently processing: CAESAR562_1_0000.nii.gz
# Currently processing: CAESAR446_0_0000.nii.gz
# Currently processing: CAESAR461_1_0000.nii.gz
# Currently processing: CAESAR177_0_0000.nii.gz
# Currently processing: CAESAR409_1_0000.nii.gz
# Currently processing: CAESAR182_1_0000.nii.gz
# Currently processing: CAESAR169_0_0000.nii.gz
# Currently processing: CAESAR112_1_0000.nii.gz
# Currently processing: CAESAR066_1_0000.nii.gz
# Currently processing: CAESAR058_1_0000.nii.gz
# Currently processing: CAESAR446_1_0000.nii.gz
# Currently processing: CAESAR256_1_0000.nii.gz
# Currently processing: CAESAR245_1_0000.nii.gz
# Currently processing: CAESAR124_1_0000.nii.gz
# Currently processing: CAESAR498_2_0000.nii.gz
# Currently processing: CAESAR208_2_0000.nii.gz
# Currently processing: CAESAR534_1_0000.nii.gz
# Currently processing: CAESAR021_1_0000.nii.gz
# Currently processing: CAESAR456_1_0000.nii.gz
# Currently processing: CAESAR131_1_0000.nii.gz
# Currently processing: CAESAR175_1_0000.nii.gz
# Currently processing: CAESAR580_1_0000.nii.gz
# Currently processing: CAESAR101_0_0000.nii.gz
# Currently processing: CAESAR075_2_0000.nii.gz
# Currently processing: CAESAR072_0_0000.nii.gz
# Currently processing: CAESAR200_1_0000.nii.gz
# Currently processing: CAESAR489_0_0000.nii.gz
# Currently processing: CAESAR447_1_0000.nii.gz
# Currently processing: CAESAR012_0_0000.nii.gz
# Currently processing: CAESAR054_0_0000.nii.gz
# Currently processing: CAESAR176_0_0000.nii.gz
# Currently processing: CAESAR533_0_0000.nii.gz
# Currently processing: CAESAR033_0_0000.nii.gz
# Currently processing: CAESAR140_1_0000.nii.gz
# Currently processing: CAESAR511_1_0000.nii.gz
# Currently processing: CAESAR070_0_0000.nii.gz
# Currently processing: CAESAR204_0_0000.nii.gz
# Currently processing: CAESAR506_0_0000.nii.gz
# Currently processing: CAESAR102_2_0000.nii.gz
# Currently processing: CAESAR053_1_0000.nii.gz
# Currently processing: CAESAR330_0_0000.nii.gz
# Currently processing: CAESAR434_1_0000.nii.gz
# Currently processing: CAESAR421_1_0000.nii.gz
# Currently processing: CAESAR166_0_0000.nii.gz
# Currently processing: CAESAR349_2_0000.nii.gz
# Currently processing: CAESAR404_0_0000.nii.gz
# Currently processing: CAESAR247_1_0000.nii.gz
# Currently processing: CAESAR516_0_0000.nii.gz
# Currently processing: CAESAR347_0_0000.nii.gz
# Currently processing: CAESAR117_0_0000.nii.gz
# Currently processing: CAESAR082_0_0000.nii.gz
# Currently processing: CAESAR324_2_0000.nii.gz
# Currently processing: CAESAR118_1_0000.nii.gz
# Currently processing: CAESAR077_0_0000.nii.gz
# Currently processing: CAESAR220_1_0000.nii.gz
# Currently processing: CAESAR315_0_0000.nii.gz
# Currently processing: CAESAR406_0_0000.nii.gz
# Currently processing: CAESAR359_0_0000.nii.gz
# Currently processing: CAESAR284_1_0000.nii.gz
# Currently processing: CAESAR507_0_0000.nii.gz
# Currently processing: CAESAR285_0_0000.nii.gz
# Currently processing: CAESAR448_1_0000.nii.gz
# Currently processing: CAESAR354_1_0000.nii.gz
# Currently processing: CAESAR148_1_0000.nii.gz
# Currently processing: CAESAR457_0_0000.nii.gz
# Currently processing: CAESAR332_0_0000.nii.gz
# Currently processing: CAESAR356_0_0000.nii.gz
# Currently processing: CAESAR175_0_0000.nii.gz
# Currently processing: CAESAR127_0_0000.nii.gz
# Currently processing: CAESAR326_0_0000.nii.gz
# Currently processing: CAESAR477_0_0000.nii.gz
# Currently processing: CAESAR158_0_0000.nii.gz
# Currently processing: CAESAR134_1_0000.nii.gz
# Currently processing: CAESAR122_1_0000.nii.gz
# Currently processing: CAESAR093_1_0000.nii.gz
# Currently processing: CAESAR504_1_0000.nii.gz
# Currently processing: CAESAR315_1_0000.nii.gz
# Currently processing: CAESAR137_0_0000.nii.gz
# Currently processing: CAESAR535_0_0000.nii.gz
# Currently processing: CAESAR063_0_0000.nii.gz
# Currently processing: CAESAR207_0_0000.nii.gz
# Currently processing: CAESAR513_1_0000.nii.gz
# Currently processing: CAESAR571_1_0000.nii.gz
# Currently processing: CAESAR174_1_0000.nii.gz
# Currently processing: CAESAR338_0_0000.nii.gz
# Currently processing: CAESAR226_2_0000.nii.gz
# Currently processing: CAESAR266_1_0000.nii.gz
# Currently processing: CAESAR300_1_0000.nii.gz
# Currently processing: CAESAR157_2_0000.nii.gz
# Currently processing: CAESAR322_0_0000.nii.gz
# Currently processing: CAESAR271_1_0000.nii.gz
# Currently processing: CAESAR423_0_0000.nii.gz
# Currently processing: CAESAR388_0_0000.nii.gz
# Currently processing: CAESAR182_0_0000.nii.gz
# Currently processing: CAESAR232_0_0000.nii.gz
# Currently processing: CAESAR204_1_0000.nii.gz
# Currently processing: CAESAR570_0_0000.nii.gz
# Currently processing: CAESAR325_0_0000.nii.gz
# Currently processing: CAESAR298_0_0000.nii.gz
# Currently processing: CAESAR487_0_0000.nii.gz
# Currently processing: CAESAR196_0_0000.nii.gz
# Currently processing: CAESAR073_0_0000.nii.gz
# Currently processing: CAESAR412_0_0000.nii.gz
# Currently processing: CAESAR386_1_0000.nii.gz
# Currently processing: CAESAR066_0_0000.nii.gz
# Currently processing: CAESAR449_0_0000.nii.gz
# Currently processing: CAESAR121_1_0000.nii.gz
# Currently processing: CAESAR310_2_0000.nii.gz
# Currently processing: CAESAR444_1_0000.nii.gz
# Currently processing: CAESAR253_2_0000.nii.gz
# Currently processing: CAESAR013_1_0000.nii.gz
# Currently processing: CAESAR559_1_0000.nii.gz
# Currently processing: CAESAR358_0_0000.nii.gz
# Currently processing: CAESAR207_1_0000.nii.gz
# Currently processing: CAESAR208_0_0000.nii.gz
# Currently processing: CAESAR306_0_0000.nii.gz
# Currently processing: CAESAR033_2_0000.nii.gz
# Currently processing: CAESAR143_1_0000.nii.gz
# Currently processing: CAESAR062_0_0000.nii.gz
# Currently processing: CAESAR213_0_0000.nii.gz
# Currently processing: CAESAR210_0_0000.nii.gz
# Currently processing: CAESAR394_1_0000.nii.gz
# Currently processing: CAESAR049_0_0000.nii.gz
# Currently processing: CAESAR092_1_0000.nii.gz
# Currently processing: CAESAR157_1_0000.nii.gz
# Currently processing: CAESAR100_0_0000.nii.gz
# Currently processing: CAESAR584_0_0000.nii.gz
# Currently processing: CAESAR142_1_0000.nii.gz
# Currently processing: CAESAR418_1_0000.nii.gz
# Currently processing: CAESAR044_1_0000.nii.gz
# Currently processing: CAESAR537_1_0000.nii.gz
# Currently processing: CAESAR047_0_0000.nii.gz
# Currently processing: CAESAR018_2_0000.nii.gz
# Currently processing: CAESAR354_0_0000.nii.gz
# Currently processing: CAESAR015_0_0000.nii.gz
# Currently processing: CAESAR323_0_0000.nii.gz
# Currently processing: CAESAR029_0_0000.nii.gz
# Currently processing: CAESAR471_0_0000.nii.gz
# Currently processing: CAESAR132_0_0000.nii.gz
# Currently processing: CAESAR490_1_0000.nii.gz
# Currently processing: CAESAR309_0_0000.nii.gz
# Currently processing: CAESAR402_1_0000.nii.gz
# Currently processing: CAESAR481_1_0000.nii.gz
# Currently processing: CAESAR362_1_0000.nii.gz
# Currently processing: CAESAR139_0_0000.nii.gz
# Currently processing: CAESAR247_0_0000.nii.gz
# Currently processing: CAESAR293_0_0000.nii.gz
# Currently processing: CAESAR093_0_0000.nii.gz
# Currently processing: CAESAR515_0_0000.nii.gz
# Currently processing: CAESAR269_2_0000.nii.gz
# Currently processing: CAESAR410_1_0000.nii.gz
# Currently processing: CAESAR167_0_0000.nii.gz
# Currently processing: CAESAR524_1_0000.nii.gz
# Currently processing: CAESAR419_1_0000.nii.gz
# Currently processing: CAESAR370_2_0000.nii.gz
# Currently processing: CAESAR098_1_0000.nii.gz
# Currently processing: CAESAR236_2_0000.nii.gz
# Currently processing: CAESAR372_1_0000.nii.gz
# Currently processing: CAESAR235_0_0000.nii.gz
# Currently processing: CAESAR102_1_0000.nii.gz
# Currently processing: CAESAR029_1_0000.nii.gz
# Currently processing: CAESAR084_0_0000.nii.gz
# Currently processing: CAESAR375_0_0000.nii.gz
# Currently processing: CAESAR101_1_0000.nii.gz
# Currently processing: CAESAR425_0_0000.nii.gz
# Currently processing: CAESAR415_1_0000.nii.gz
# Currently processing: CAESAR344_2_0000.nii.gz
# Currently processing: CAESAR048_0_0000.nii.gz
# Currently processing: CAESAR118_0_0000.nii.gz
# Currently processing: CAESAR113_1_0000.nii.gz
# Currently processing: CAESAR027_1_0000.nii.gz
# Currently processing: CAESAR259_0_0000.nii.gz
# Currently processing: CAESAR186_1_0000.nii.gz
# Currently processing: CAESAR562_0_0000.nii.gz
# Currently processing: CAESAR139_1_0000.nii.gz
# Currently processing: CAESAR391_1_0000.nii.gz
# Currently processing: CAESAR192_0_0000.nii.gz
# Currently processing: CAESAR229_1_0000.nii.gz
# Currently processing: CAESAR247_2_0000.nii.gz
# Currently processing: CAESAR426_1_0000.nii.gz
# Currently processing: CAESAR156_0_0000.nii.gz
# Currently processing: CAESAR376_1_0000.nii.gz
# Currently processing: CAESAR392_1_0000.nii.gz
# Currently processing: CAESAR461_0_0000.nii.gz
# Currently processing: CAESAR394_2_0000.nii.gz
# Currently processing: CAESAR118_2_0000.nii.gz
# Currently processing: CAESAR255_0_0000.nii.gz
# Currently processing: CAESAR171_0_0000.nii.gz
# Currently processing: CAESAR236_1_0000.nii.gz
# Currently processing: CAESAR528_1_0000.nii.gz
# Currently processing: CAESAR075_1_0000.nii.gz
# Currently processing: CAESAR295_0_0000.nii.gz
# Currently processing: CAESAR484_0_0000.nii.gz
# Currently processing: CAESAR475_1_0000.nii.gz
# Currently processing: CAESAR083_2_0000.nii.gz
# Currently processing: CAESAR351_2_0000.nii.gz
# Currently processing: CAESAR421_0_0000.nii.gz
# Currently processing: CAESAR417_0_0000.nii.gz
# Currently processing: CAESAR173_0_0000.nii.gz
# Currently processing: CAESAR128_1_0000.nii.gz
# Currently processing: CAESAR322_1_0000.nii.gz
# Currently processing: CAESAR030_0_0000.nii.gz
# Currently processing: CAESAR076_1_0000.nii.gz
# Currently processing: CAESAR342_0_0000.nii.gz
# Currently processing: CAESAR368_1_0000.nii.gz
# Currently processing: CAESAR154_1_0000.nii.gz
# Currently processing: CAESAR533_1_0000.nii.gz
# Currently processing: CAESAR086_0_0000.nii.gz
# Currently processing: CAESAR180_1_0000.nii.gz
# Currently processing: CAESAR461_2_0000.nii.gz
# Currently processing: CAESAR564_1_0000.nii.gz
# Currently processing: CAESAR381_0_0000.nii.gz
# Currently processing: CAESAR308_0_0000.nii.gz
# Currently processing: CAESAR466_1_0000.nii.gz
# Currently processing: CAESAR245_0_0000.nii.gz
# Currently processing: CAESAR271_0_0000.nii.gz
# Currently processing: CAESAR043_1_0000.nii.gz
# Currently processing: CAESAR339_0_0000.nii.gz
# Currently processing: CAESAR267_0_0000.nii.gz
# Currently processing: CAESAR255_2_0000.nii.gz
# Currently processing: CAESAR189_1_0000.nii.gz
# Currently processing: CAESAR047_2_0000.nii.gz
# Currently processing: CAESAR473_0_0000.nii.gz
# Currently processing: CAESAR426_0_0000.nii.gz
# Currently processing: CAESAR513_0_0000.nii.gz
# Currently processing: CAESAR018_1_0000.nii.gz
# Currently processing: CAESAR473_2_0000.nii.gz
# Currently processing: CAESAR347_1_0000.nii.gz
# Currently processing: CAESAR298_1_0000.nii.gz
# Currently processing: CAESAR065_2_0000.nii.gz
# Currently processing: CAESAR266_0_0000.nii.gz
# Currently processing: CAESAR013_2_0000.nii.gz
# Currently processing: CAESAR242_0_0000.nii.gz
# Currently processing: CAESAR297_0_0000.nii.gz
# Currently processing: CAESAR052_1_0000.nii.gz
# Currently processing: CAESAR078_1_0000.nii.gz
# Currently processing: CAESAR504_0_0000.nii.gz
# Currently processing: CAESAR540_0_0000.nii.gz
# Currently processing: CAESAR173_1_0000.nii.gz
# Currently processing: CAESAR455_0_0000.nii.gz
# Currently processing: CAESAR208_1_0000.nii.gz
# Currently processing: CAESAR197_1_0000.nii.gz
# Currently processing: CAESAR311_0_0000.nii.gz
# Currently processing: CAESAR308_1_0000.nii.gz
# Currently processing: CAESAR368_0_0000.nii.gz
# Currently processing: CAESAR430_0_0000.nii.gz
# Currently processing: CAESAR026_1_0000.nii.gz
# Currently processing: CAESAR353_0_0000.nii.gz
# Currently processing: CAESAR544_1_0000.nii.gz
# Currently processing: CAESAR309_1_0000.nii.gz
# Currently processing: CAESAR030_1_0000.nii.gz
# Currently processing: CAESAR547_0_0000.nii.gz
# Currently processing: CAESAR338_1_0000.nii.gz
# Currently processing: CAESAR324_0_0000.nii.gz
# Currently processing: CAESAR189_0_0000.nii.gz
# Currently processing: CAESAR348_2_0000.nii.gz
# Currently processing: CAESAR075_0_0000.nii.gz
# Currently processing: CAESAR560_1_0000.nii.gz
# Currently processing: CAESAR032_0_0000.nii.gz
# Currently processing: CAESAR121_0_0000.nii.gz
# Currently processing: CAESAR129_0_0000.nii.gz
# Currently processing: CAESAR306_2_0000.nii.gz
# Currently processing: CAESAR303_1_0000.nii.gz
# Currently processing: CAESAR583_1_0000.nii.gz
# Currently processing: CAESAR566_1_0000.nii.gz
# Currently processing: CAESAR209_0_0000.nii.gz
# Currently processing: CAESAR004_1_0000.nii.gz
# Currently processing: CAESAR037_0_0000.nii.gz
# Currently processing: CAESAR013_0_0000.nii.gz
# Currently processing: CAESAR159_1_0000.nii.gz
# Currently processing: CAESAR413_1_0000.nii.gz
# Currently processing: CAESAR221_0_0000.nii.gz
# Currently processing: CAESAR107_0_0000.nii.gz
# Currently processing: CAESAR237_1_0000.nii.gz
# Currently processing: CAESAR287_0_0000.nii.gz
# Currently processing: CAESAR575_1_0000.nii.gz
# Currently processing: CAESAR304_0_0000.nii.gz
# Currently processing: CAESAR287_1_0000.nii.gz
# Currently processing: CAESAR271_2_0000.nii.gz
# Currently processing: CAESAR058_0_0000.nii.gz
# Currently processing: CAESAR384_0_0000.nii.gz
# Currently processing: CAESAR584_1_0000.nii.gz
# Currently processing: CAESAR046_1_0000.nii.gz
# Currently processing: CAESAR529_0_0000.nii.gz
# Currently processing: CAESAR216_0_0000.nii.gz
# Currently processing: CAESAR257_1_0000.nii.gz
# Currently processing: CAESAR545_1_0000.nii.gz
# Currently processing: CAESAR348_1_0000.nii.gz
# Currently processing: CAESAR373_0_0000.nii.gz
# Currently processing: CAESAR191_0_0000.nii.gz
# Currently processing: CAESAR198_1_0000.nii.gz
# Currently processing: CAESAR229_0_0000.nii.gz
# Currently processing: CAESAR018_0_0000.nii.gz
# Currently processing: CAESAR335_0_0000.nii.gz
# Currently processing: CAESAR017_0_0000.nii.gz
# Currently processing: CAESAR087_2_0000.nii.gz
# Currently processing: CAESAR293_1_0000.nii.gz
# Currently processing: CAESAR237_0_0000.nii.gz
# Currently processing: CAESAR165_1_0000.nii.gz
# Currently processing: CAESAR067_1_0000.nii.gz
# Currently processing: CAESAR026_0_0000.nii.gz
# Currently processing: CAESAR194_1_0000.nii.gz
# Currently processing: CAESAR116_1_0000.nii.gz
# Currently processing: CAESAR358_2_0000.nii.gz
# Currently processing: CAESAR154_2_0000.nii.gz
# Currently processing: CAESAR318_1_0000.nii.gz
# Currently processing: CAESAR537_2_0000.nii.gz
# Currently processing: CAESAR304_1_0000.nii.gz
# Currently processing: CAESAR490_0_0000.nii.gz
# Currently processing: CAESAR185_1_0000.nii.gz
# Currently processing: CAESAR054_1_0000.nii.gz
# Currently processing: CAESAR232_1_0000.nii.gz
# Currently processing: CAESAR017_1_0000.nii.gz
# Currently processing: CAESAR579_1_0000.nii.gz
# Currently processing: CAESAR129_1_0000.nii.gz
# Currently processing: CAESAR055_1_0000.nii.gz
# Currently processing: CAESAR400_1_0000.nii.gz
# Currently processing: CAESAR540_1_0000.nii.gz
# Currently processing: CAESAR454_0_0000.nii.gz
# Currently processing: CAESAR308_2_0000.nii.gz
# Currently processing: CAESAR051_1_0000.nii.gz
# Currently processing: CAESAR135_1_0000.nii.gz
# Currently processing: CAESAR048_1_0000.nii.gz
# Currently processing: CAESAR448_0_0000.nii.gz
# Currently processing: CAESAR444_0_0000.nii.gz
# Currently processing: CAESAR297_2_0000.nii.gz
# Currently processing: CAESAR313_1_0000.nii.gz
# Currently processing: CAESAR522_0_0000.nii.gz
# Currently processing: CAESAR082_1_0000.nii.gz
# Currently processing: CAESAR200_0_0000.nii.gz
# Currently processing: CAESAR367_1_0000.nii.gz
# Currently processing: CAESAR581_1_0000.nii.gz
# Currently processing: CAESAR455_1_0000.nii.gz
# Currently processing: CAESAR344_1_0000.nii.gz
# Currently processing: CAESAR584_2_0000.nii.gz
# Currently processing: CAESAR152_0_0000.nii.gz
# Currently processing: CAESAR138_0_0000.nii.gz
# Currently processing: CAESAR390_1_0000.nii.gz
# Currently processing: CAESAR538_2_0000.nii.gz
# Currently processing: CAESAR165_0_0000.nii.gz
# Currently processing: CAESAR372_2_0000.nii.gz
# Currently processing: CAESAR319_0_0000.nii.gz
# Currently processing: CAESAR300_0_0000.nii.gz
# Currently processing: CAESAR123_1_0000.nii.gz
# Currently processing: CAESAR098_0_0000.nii.gz
# Currently processing: CAESAR230_1_0000.nii.gz
# Currently processing: CAESAR447_0_0000.nii.gz
# Currently processing: CAESAR286_2_0000.nii.gz
# Currently processing: CAESAR502_2_0000.nii.gz
# Currently processing: CAESAR220_0_0000.nii.gz
# Currently processing: CAESAR521_0_0000.nii.gz
# Currently processing: CAESAR169_1_0000.nii.gz
# Currently processing: CAESAR152_1_0000.nii.gz
# Currently processing: CAESAR130_1_0000.nii.gz
# Currently processing: CAESAR366_1_0000.nii.gz
# Currently processing: CAESAR528_2_0000.nii.gz
# Currently processing: CAESAR291_2_0000.nii.gz
# Currently processing: CAESAR015_1_0000.nii.gz
# Currently processing: CAESAR400_0_0000.nii.gz
# Currently processing: CAESAR334_0_0000.nii.gz
# Currently processing: CAESAR378_1_0000.nii.gz
# Currently processing: CAESAR053_0_0000.nii.gz
# Currently processing: CAESAR074_1_0000.nii.gz
# Currently processing: CAESAR124_0_0000.nii.gz
# Currently processing: CAESAR209_2_0000.nii.gz
# Currently processing: CAESAR072_1_0000.nii.gz
# Currently processing: CAESAR559_0_0000.nii.gz
# Currently processing: CAESAR166_2_0000.nii.gz
# Currently processing: CAESAR319_1_0000.nii.gz
# Currently processing: CAESAR158_1_0000.nii.gz
# Currently processing: CAESAR569_0_0000.nii.gz
# Currently processing: CAESAR205_1_0000.nii.gz
# Currently processing: CAESAR116_0_0000.nii.gz
# Currently processing: CAESAR296_1_0000.nii.gz
# Currently processing: CAESAR034_0_0000.nii.gz
# Currently processing: CAESAR453_0_0000.nii.gz
# Currently processing: CAESAR256_0_0000.nii.gz
# Currently processing: CAESAR435_2_0000.nii.gz
# Currently processing: CAESAR383_1_0000.nii.gz
# Currently processing: CAESAR043_0_0000.nii.gz
# Currently processing: CAESAR253_0_0000.nii.gz
# Currently processing: CAESAR021_0_0000.nii.gz
# Currently processing: CAESAR267_2_0000.nii.gz
# Currently processing: CAESAR580_0_0000.nii.gz
# Currently processing: CAESAR236_0_0000.nii.gz
# Currently processing: CAESAR530_1_0000.nii.gz
# Currently processing: CAESAR078_2_0000.nii.gz
# Currently processing: CAESAR353_1_0000.nii.gz
# Currently processing: CAESAR538_0_0000.nii.gz
# Currently processing: CAESAR391_0_0000.nii.gz
# Currently processing: CAESAR318_2_0000.nii.gz
# Currently processing: CAESAR318_0_0000.nii.gz
# Currently processing: CAESAR041_0_0000.nii.gz
# Currently processing: CAESAR422_0_0000.nii.gz
# Currently processing: CAESAR034_1_0000.nii.gz
# Currently processing: CAESAR500_0_0000.nii.gz
# Currently processing: CAESAR076_0_0000.nii.gz
# Currently processing: CAESAR410_0_0000.nii.gz
# Currently processing: CAESAR085_1_0000.nii.gz
# Currently processing: CAESAR423_2_0000.nii.gz
# Currently processing: CAESAR489_1_0000.nii.gz
# Currently processing: CAESAR154_0_0000.nii.gz
# Currently processing: CAESAR348_0_0000.nii.gz
# Currently processing: CAESAR548_0_0000.nii.gz
# Currently processing: CAESAR223_1_0000.nii.gz
# Currently processing: CAESAR241_0_0000.nii.gz
# Currently processing: CAESAR463_1_0000.nii.gz
# Currently processing: CAESAR435_1_0000.nii.gz
# Currently processing: CAESAR425_1_0000.nii.gz
# Currently processing: CAESAR087_1_0000.nii.gz
# Currently processing: CAESAR556_1_0000.nii.gz
# Currently processing: CAESAR125_1_0000.nii.gz
# Currently processing: CAESAR430_1_0000.nii.gz
# Currently processing: CAESAR137_1_0000.nii.gz
# Currently processing: CAESAR210_1_0000.nii.gz
# Currently processing: CAESAR498_0_0000.nii.gz
# Currently processing: CAESAR323_1_0000.nii.gz
# Currently processing: CAESAR041_1_0000.nii.gz
# Currently processing: CAESAR235_2_0000.nii.gz
# Currently processing: CAESAR205_0_0000.nii.gz
# Currently processing: CAESAR200_2_0000.nii.gz
# Currently processing: CAESAR212_0_0000.nii.gz
# Currently processing: CAESAR524_0_0000.nii.gz
# Currently processing: CAESAR050_1_0000.nii.gz
# Currently processing: CAESAR102_0_0000.nii.gz
# Currently processing: CAESAR218_2_0000.nii.gz
# Currently processing: CAESAR486_1_0000.nii.gz
# Currently processing: CAESAR007_1_0000.nii.gz
# Currently processing: CAESAR061_1_0000.nii.gz
# Currently processing: CAESAR197_0_0000.nii.gz
# Currently processing: CAESAR407_1_0000.nii.gz
# Currently processing: CAESAR506_1_0000.nii.gz
# Currently processing: CAESAR122_2_0000.nii.gz
# Currently processing: CAESAR313_2_0000.nii.gz
# Currently processing: CAESAR186_0_0000.nii.gz
# Currently processing: CAESAR070_2_0000.nii.gz
# Currently processing: CAESAR472_0_0000.nii.gz
# Currently processing: CAESAR107_2_0000.nii.gz
# Currently processing: CAESAR157_0_0000.nii.gz
# Currently processing: CAESAR299_1_0000.nii.gz
# Currently processing: CAESAR264_1_0000.nii.gz
# Currently processing: CAESAR456_0_0000.nii.gz
# Currently processing: CAESAR375_1_0000.nii.gz
# Currently processing: CAESAR384_2_0000.nii.gz
# Currently processing: CAESAR046_0_0000.nii.gz
# Currently processing: CAESAR422_1_0000.nii.gz
# Currently processing: CAESAR341_2_0000.nii.gz
# Currently processing: CAESAR341_0_0000.nii.gz
# Currently processing: CAESAR519_1_0000.nii.gz
# Currently processing: CAESAR194_2_0000.nii.gz
# Currently processing: CAESAR142_0_0000.nii.gz
# Currently processing: CAESAR535_1_0000.nii.gz
# Currently processing: CAESAR325_1_0000.nii.gz
# Currently processing: CAESAR068_1_0000.nii.gz
# Currently processing: CAESAR433_0_0000.nii.gz
# Currently processing: CAESAR087_0_0000.nii.gz
# Currently processing: CAESAR313_0_0000.nii.gz
# Currently processing: CAESAR332_1_0000.nii.gz
# Currently processing: CAESAR423_1_0000.nii.gz
# Currently processing: CAESAR107_1_0000.nii.gz
# Currently processing: CAESAR311_1_0000.nii.gz
# Currently processing: CAESAR125_0_0000.nii.gz
# Currently processing: CAESAR166_1_0000.nii.gz
# Currently processing: CAESAR340_1_0000.nii.gz
# Currently processing: CAESAR383_0_0000.nii.gz
# Currently processing: CAESAR213_1_0000.nii.gz
# Currently processing: CAESAR451_0_0000.nii.gz
# Currently processing: CAESAR402_0_0000.nii.gz
# Currently processing: CAESAR564_0_0000.nii.gz
# Currently processing: CAESAR004_0_0000.nii.gz
# Currently processing: CAESAR381_1_0000.nii.gz
# Currently processing: CAESAR267_1_0000.nii.gz
# Currently processing: CAESAR426_2_0000.nii.gz
# Currently processing: CAESAR438_1_0000.nii.gz
# Currently processing: CAESAR376_0_0000.nii.gz
# Currently processing: CAESAR110_1_0000.nii.gz
# Currently processing: CAESAR420_1_0000.nii.gz
# Currently processing: CAESAR362_2_0000.nii.gz
# Currently processing: CAESAR291_0_0000.nii.gz
# Currently processing: CAESAR242_2_0000.nii.gz
# Currently processing: CAESAR352_1_0000.nii.gz
# Currently processing: CAESAR472_1_0000.nii.gz
# Currently processing: CAESAR264_0_0000.nii.gz
# Currently processing: CAESAR127_1_0000.nii.gz
# Currently processing: CAESAR277_0_0000.nii.gz
# Currently processing: CAESAR230_0_0000.nii.gz
# Currently processing: CAESAR144_1_0000.nii.gz
# Currently processing: CAESAR159_0_0000.nii.gz
# Currently processing: CAESAR038_0_0000.nii.gz
# Currently processing: CAESAR463_0_0000.nii.gz
# Currently processing: CAESAR089_1_0000.nii.gz
# Currently processing: CAESAR296_0_0000.nii.gz
# Currently processing: CAESAR494_1_0000.nii.gz
# Currently processing: CAESAR443_1_0000.nii.gz
# Currently processing: CAESAR033_1_0000.nii.gz
# Currently processing: CAESAR192_1_0000.nii.gz
# Currently processing: CAESAR104_0_0000.nii.gz
# Currently processing: CAESAR128_0_0000.nii.gz
# Currently processing: CAESAR295_1_0000.nii.gz
# Currently processing: CAESAR545_0_0000.nii.gz
# Currently processing: CAESAR303_0_0000.nii.gz
# Currently processing: CAESAR334_1_0000.nii.gz
# Currently processing: CAESAR055_0_0000.nii.gz
# Currently processing: CAESAR327_1_0000.nii.gz
# Currently processing: CAESAR538_1_0000.nii.gz
# Currently processing: CAESAR357_0_0000.nii.gz
# Currently processing: CAESAR117_1_0000.nii.gz
# Currently processing: CAESAR052_0_0000.nii.gz
# Currently processing: CAESAR095_0_0000.nii.gz
# Currently processing: CAESAR415_0_0000.nii.gz
# Currently processing: CAESAR212_1_0000.nii.gz
# Currently processing: CAESAR548_1_0000.nii.gz
# Currently processing: CAESAR134_0_0000.nii.gz
# Currently processing: CAESAR370_0_0000.nii.gz
# Currently processing: CAESAR241_1_0000.nii.gz
# Currently processing: CAESAR341_1_0000.nii.gz
# Currently processing: CAESAR565_1_0000.nii.gz
# Currently processing: CAESAR162_1_0000.nii.gz
# Currently processing: CAESAR185_0_0000.nii.gz
# Currently processing: CAESAR434_0_0000.nii.gz
# Currently processing: CAESAR385_1_0000.nii.gz
# Currently processing: CAESAR186_2_0000.nii.gz
# Currently processing: CAESAR516_1_0000.nii.gz
# Currently processing: CAESAR501_1_0000.nii.gz
# Currently processing: CAESAR221_1_0000.nii.gz
# Currently processing: CAESAR132_1_0000.nii.gz
# Currently processing: CAESAR440_0_0000.nii.gz
# Currently processing: CAESAR511_0_0000.nii.gz
# Currently processing: CAESAR177_1_0000.nii.gz
# Currently processing: CAESAR123_0_0000.nii.gz
# Currently processing: CAESAR340_0_0000.nii.gz
# Currently processing: CAESAR392_0_0000.nii.gz
# Currently processing: CAESAR167_1_0000.nii.gz
# Currently processing: CAESAR378_0_0000.nii.gz
# Currently processing: CAESAR336_1_0000.nii.gz
# Currently processing: CAESAR001_0_0000.nii.gz
# Currently processing: CAESAR366_0_0000.nii.gz
# Currently processing: CAESAR095_1_0000.nii.gz
# Currently processing: CAESAR486_0_0000.nii.gz
# Currently processing: CAESAR065_1_0000.nii.gz
# Currently processing: CAESAR185_2_0000.nii.gz
# Currently processing: CAESAR442_1_0000.nii.gz
# Currently processing: CAESAR148_0_0000.nii.gz
# Currently processing: CAESAR550_1_0000.nii.gz
# Currently processing: CAESAR570_1_0000.nii.gz
# Currently processing: CAESAR477_1_0000.nii.gz
# Currently processing: CAESAR065_0_0000.nii.gz
# Currently processing: CAESAR300_2_0000.nii.gz
# Currently processing: CAESAR138_1_0000.nii.gz
# Currently processing: CAESAR096_0_0000.nii.gz
# Currently processing: CAESAR335_1_0000.nii.gz
# Currently processing: CAESAR502_1_0000.nii.gz
# Currently processing: CAESAR458_0_0000.nii.gz
# Currently processing: CAESAR411_1_0000.nii.gz
# Currently processing: CAESAR435_0_0000.nii.gz
# Currently processing: CAESAR394_0_0000.nii.gz
# Currently processing: CAESAR297_1_0000.nii.gz
# Currently processing: CAESAR136_0_0000.nii.gz
# Currently processing: CAESAR575_0_0000.nii.gz
# Currently processing: CAESAR097_1_0000.nii.gz
# Currently processing: CAESAR038_1_0000.nii.gz
# Currently processing: CAESAR359_1_0000.nii.gz
# Currently processing: CAESAR547_1_0000.nii.gz
# Currently processing: CAESAR336_0_0000.nii.gz
# Currently processing: CAESAR451_1_0000.nii.gz
# Currently processing: CAESAR512_0_0000.nii.gz
# Currently processing: CAESAR218_1_0000.nii.gz
# Currently processing: CAESAR306_1_0000.nii.gz
# Currently processing: CAESAR412_1_0000.nii.gz
# Currently processing: CAESAR122_0_0000.nii.gz
# Currently processing: CAESAR112_0_0000.nii.gz
# Currently processing: CAESAR473_1_0000.nii.gz
# Currently processing: CAESAR253_1_0000.nii.gz
# Currently processing: CAESAR153_1_0000.nii.gz
# Currently processing: CAESAR562_2_0000.nii.gz
# Currently processing: CAESAR130_0_0000.nii.gz
# Currently processing: CAESAR255_1_0000.nii.gz
# Currently processing: CAESAR457_1_0000.nii.gz
# Currently processing: CAESAR440_1_0000.nii.gz
# Currently processing: CAESAR131_2_0000.nii.gz
# Currently processing: CAESAR420_0_0000.nii.gz
# Currently processing: CAESAR191_1_0000.nii.gz
# Currently processing: CAESAR068_0_0000.nii.gz
# Currently processing: CAESAR327_0_0000.nii.gz
# Currently processing: CAESAR409_0_0000.nii.gz
# Currently processing: CAESAR362_0_0000.nii.gz
# Currently processing: CAESAR077_1_0000.nii.gz
# Currently processing: CAESAR449_1_0000.nii.gz
# Currently processing: CAESAR406_1_0000.nii.gz
# Currently processing: CAESAR529_1_0000.nii.gz
# Currently processing: CAESAR502_0_0000.nii.gz
# Currently processing: CAESAR092_0_0000.nii.gz
# Currently processing: CAESAR515_1_0000.nii.gz
# Currently processing: CAESAR339_1_0000.nii.gz
# Currently processing: CAESAR010_0_0000.nii.gz
# Currently processing: CAESAR198_0_0000.nii.gz
# Currently processing: CAESAR032_1_0000.nii.gz
# Currently processing: CAESAR286_0_0000.nii.gz
# Currently processing: CAESAR113_0_0000.nii.gz
# Currently processing: CAESAR180_0_0000.nii.gz
# Currently processing: CAESAR522_1_0000.nii.gz
# Currently processing: CAESAR224_0_0000.nii.gz
# Currently processing: CAESAR530_0_0000.nii.gz
# Currently processing: CAESAR494_0_0000.nii.gz

# %%
"""
copies scans of patients that have both 0 and 1 scans
"""

# Create a dictionary to track patient scans
patient_scans = {}

# Iterate through all scans
for scan in os.listdir(tumor_segmentations_path):
    # Extract the patient ID and scan type (0 or 1)

    patient_id, scan_type = scan.split("_")[0], scan[0:-7].split("_")[1]

    # Add the scan type to the patient's record
    if patient_id not in patient_scans:
        patient_scans[patient_id] = set()
    patient_scans[patient_id].add(scan_type)

# Move scans of patients that have both 0 and 1 scans
for patient_id, scan_types in patient_scans.items():
    if "0" in scan_types and "1" in scan_types:
        first_scan = f"{patient_id}_0_tumor.nii.gz"
        second_scan = f"{patient_id}_1_tumor.nii.gz"
        shutil.copy(src=os.path.join(tumor_segmentations_path, first_scan), dst=os.path.join(paired_tumor_scans_path, first_scan))
        shutil.copy(src=os.path.join(tumor_segmentations_path, second_scan), dst=os.path.join(paired_tumor_scans_path, second_scan))

# %% [markdown]
# ## Weighted tumor mask data preparation

# %% [markdown]
# ### Sanity checks

# %%
# check with resizing if segmentations are still correct
